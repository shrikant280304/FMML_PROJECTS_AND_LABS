# %% [markdown]
# <a href="https://colab.research.google.com/github/shrikant280304/FMML_PROJECTS_AND_LABS/blob/main/M8_L3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-05-11 03:48:12--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   182MB/s    in 0.4s
#
# 2025-05-11 03:48:13 (182 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 10173  1710.06542v1  Deep reinforcement learning (RL) has proven a ...    cs
# 10792   1403.5997v3  We introduce a Bayesian solution for the probl...  stat
# 7398   1712.04688v1  In variable or graph selection problems, findi...  stat
# 7166   1710.10345v3  We show that gradient descent on an unregulari...  stat
# 6483   1702.07360v2  In this paper we propose a synergistic melting...  stat
# ...             ...                                                ...   ...
# 39114   1311.5830v1  Electron tomography usually suffers from so ca...    cs
# 17529  1711.10203v1  We investigate how neural networks can learn a...    cs
# 24238   1112.1200v1  We propose in this paper a tracking algorithm ...    cs
# 37860   0908.2724v1  We present a novel method for solving Canonica...  stat
# 12259  1710.11306v1  We study rank-1 {L1-norm-based TUCKER2} (L1-TU...    cs
#
#                                                    title  year  \
# 10173  Asymmetric Actor Critic for Image-Based Robot ...  2017
# 10792  Bayesian calibration for forensic evidence rep...  2014
# 7398   Stability Selection for Structured Variable Se...  2017
# 7166   The Implicit Bias of Gradient Descent on Separ...  2017
# 6483                               Neural Decision Trees  2017
# ...                                                  ...   ...
# 39114  Dictionary-Learning-Based Reconstruction Metho...  2013
# 17529  Visualisation and 'diagnostic classifiers' rev...  2017
# 24238  A multi-feature tracking algorithm enabling ad...  2011
# 37860              Sparse Canonical Correlation Analysis  2009
# 12259  The Exact Solution to Rank-1 L1-norm TUCKER2 D...  2017
#
#                                                 keywords
# 10173  [reinforcement, technique, sequential, challen...
# 10792  [introduce, recognition, background, estimatin...
# 7398   [selection, controlling, positives, notoriousl...
# 7166   [unregularized, regression, separable, converg...
# 6483   [synergistic, architecture, splitting, indepen...
# ...                                                  ...
# 39114  [tomography, artifacts, tomography, acquisitio...
# 17529  [investigate, languages, hierarchical, composi...
# 24238  [algorithm, different, displacement, distances...
# 37860  [canonical, correlation, framework, presented,...
# 12259  [decomposition, collection, decomposed, contri...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 10173    [reinforcement, technique, sequential, challen...
# 10792    [introduce, recognition, background, estimatin...
# 7398     [selection, controlling, positives, notoriousl...
# 7166     [unregularized, regression, separable, converg...
# 6483     [synergistic, architecture, splitting, indepen...
#                                ...
# 22432    [multitask, screening, discovery, applications...
# 37516    [generalization, generalizations, equational, ...
# 6555     [regression, observations, predictions, knowle...
# 21983    [estimation, dependencies, variables, financia...
# 31083    [attention, promising, advantage, representati...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8701 words.
# Out of those 4478 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="eeb9ba4a-9be4-4962-bb6e-63a7aa252d3a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eeb9ba4a-9be4-4962-bb6e-63a7aa252d3a")) {                    Plotly.newPlot(                        "eeb9ba4a-9be4-4962-bb6e-63a7aa252d3a",                        [{"x":["technique","expensive","sequential","reinforcement","randomization","performance","employing","experiments","simulator","experimentally","observations","asymmetric","promising","dangerous","simulated","significant","algorithm","significantly","simulation","challenges","transferring","observability","advantage","reporting","background","principled","likelihood","recognition","demonstrates","treatment","traditional","calibration","distribution","parameters","estimating","introduce","probabilistic","notoriously","algorithms","competing","orthogonal","positives","investigate","structured","applicability","strategies","structure","highlight","stability","increases","strengths","guidelines","selection","validation","reliability","controlling","difficult","weaknesses","demonstrated","conjunction","decreasing","optimization","convergence","generalizes","direction","understanding","functions","regularization","converges","methodology","regression","unregularized","extremely","continuing","restricted","logarithmic","separable","furthermore","supervised","probability","splitting","represent","framework","multilayer","transformations","unsupervised","activation","differentiability","requiring","demonstrate","nonlinear","integration","synergistic","architecture","separability","clustering","particular","classification","perceptron","learnable","independent","comparison","decomposing","techniques","literature","dimension","recursively","distributions","filtering","tensorflow","estimation","efficiency","including","available","implemented","nonparametric","resulting","advantages","synthetic","benchmarks","conditional","smoothing","applications","partitioning","generative","numerical","diagnosis","introduced","properties","constrained","specified","fundamental","desirable","prioritized","guaranteed","inequalities","classifiers","construct","counterparts","statistical","classical","concerned","priorities","theoretical","dimensional","embarrassingly","conditions","distributed","exponential","facilitate","communicating","conditionally","theoretically","procedure","developed","restrictive","independently","nonconjugate","empirically","variational","conjugate","inference","implementation","describes","technical","carefully","automated","consequences","interested","translation","arithmetic","connection","elimination","correction","recursive","unification","influence","historians","consistency","improving","aggregates","intermediate","mechanisms","benchmark","alternate","comparable","innovative","interesting","outperforms","examining","architectures","popularized","approaches","neighborhood","connected","surprisingly","designing","mechanism","propagation","neighbors"],"y":[248,66,77,121,7,898,39,644,18,56,74,17,134,4,61,262,814,292,79,114,13,7,102,10,82,14,69,344,55,23,201,15,205,252,62,336,151,4,584,31,16,4,140,105,51,94,361,27,33,40,27,21,166,52,22,19,142,18,120,24,8,331,123,32,68,157,230,67,27,61,121,0,48,2,52,19,14,178,177,162,14,108,563,12,42,133,33,3,38,557,64,51,2,245,6,151,258,486,18,15,130,124,8,391,124,66,9,107,65,5,198,180,233,300,88,24,152,79,148,85,99,20,401,17,126,87,48,138,216,67,42,83,33,1,26,10,114,75,15,162,94,18,1,157,185,1,169,100,54,40,5,5,43,117,197,2,42,0,98,60,9,204,115,97,47,35,71,17,20,115,12,44,7,23,24,9,46,2,40,113,7,36,55,192,3,79,15,79,263,8,113,2,434,33,73,24,48,119,81,27],"type":"bar"},{"x":["technique","expensive","sequential","reinforcement","randomization ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4478,), (4478, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8108333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Nonlinear</span> <span style=''>Spectral</span> <span style=''>Image</span> <span style=''>Fusion</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>nonlinear</span> <span style=''>spectral</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decompositions</span> <span style=''>based</span> <span style=''>on</span> <span style=''>total</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variation</span> <span style=''>(TV)</span> <span style='background-color:rgba(255, 0, 0, 0.4574898785425101);'>regularization</span> <span style=''>is</span> <span style=''>very</span> <span style=''>well</span> <span style=''>suited</span> <span style=''>for</span> <span style=''>image</span> <span style=''>fusion</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>more</span> <span style=''>general</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.8571428571428572);'>manipulation</span> <span style=''>tasks</span> <span style=''>The</span> <span style=''>well</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>localized</span> <span style=''>and</span> <span style=''>edge</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>preserving</span> <span style=''>spectral</span> <span style=''>TV</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style=''>allows</span> <span style=''>to</span> <span style=''>select</span> <span style='background-color:rgba(0, 255, 0, 0.4615384615384616);'>frequencies</span> <span style=''>of</span> <span style=''>a</span> <span style=''>certain</span> <span style=''>image</span> <span style=''>to</span> <span style=''>transfer</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>features</span> <span style=''>such</span> <span style=''>as</span> <span style=''>wrinkles</span> <span style=''>in</span> <span style=''>a</span> <span style=''>face</span> <span style=''>from</span> <span style=''>one</span> <span style=''>image</span> <span style=''>to</span> <span style=''>another</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.324074074074074);'>illustrate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.34237288135593213);'>effectiveness</span> <span style=''>of</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>approach</span> <span style=''>in</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.39372822299651555);'>numerical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparison</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>competing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>of</span> <span style=''>Poisson</span> <span style=''>image</span> <span style=''>editing</span> <span style=''>linear</span> <span style=''>osmosis</span> <span style=''>wavelet</span> <span style=''>fusion</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Laplacian</span> <span style=''>pyramid</span> <span style=''>fusion</span> <span style=''>We</span> <span style=''>conclude</span> <span style=''>that</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>spectral</span> <span style=''>TV</sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Feature</span> <span style=''>vector</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <br/><br/><span style=''>Problems</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>(ML)</span> <span style=''>can</span> <span style=''>involve</span> <span style=''>noisy</span> <span style=''>input</span> <span style=''>data</span> <span style=''>and</span> <span style=''>ML</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>methods</span> <span style=''>have</span> <span style=''>reached</span> <span style=''>limiting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>accuracies</span> <span style=''>when</span> <span style=''>based</span> <span style=''>on</span> <span style=''>standard</span> <span style=''>ML</span> <span style=''>data</span> <span style=''>sets</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consisting</span> <span style=''>of</span> <span style=''>feature</span> <span style=''>vectors</span> <span style=''>and</span> <span style=''>their</span> <span style=''>classes</span> <span style=''>Greater</span> <span style=''>accuracy</span> <span style=''>will</span> <span style=''>require</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporation</span> <span style=''>of</span> <span style=''>prior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>on</span> <span style=''>data</span> <span style=''>into</span> <span style=''>learning</span> <span style=''>We</span> <span style=''>study</span> <span style=''>methods</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularize</span> <span style=''>feature</span> <span style=''>vectors</span> <span style=''>(unsupervised</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>methods)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analogous</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>in</span> <span style=''>ML</span> <span style=''>We</span> <span style=''>study</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>(denoising)</span> <span style=''>of</span> <span style=''>ML</span> <span style=''>feature</span> <span style=''>vectors</span> <span style=''>using</span> <span style=''>Tikhonov</span> <span style=''>and</span> <span style=''>other</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>on</span> <span style=''>bf</span> <span style=''>Rn</span> <span style=''>A</span> <span style=''>feature</span> <span style=''>vector</span> <span style=''>bf</span> <span style=''>x(x</span> <span style=''>1ldotsx</span> <span style=''>n)x</span> <span style=''>q</span> <span style=''>q1n</span> <span style=''>is</span> <span style=''>viewed</span> <span style=''>as</span> <span style=''>a</span> <span style=''>function</span> <span style=''>of</span> <span style=''>its</span> <span style=''>index</span> <span style=''>q</span> <span style=''>and</span> <span style=''>smoothed</span> <span style=''>using</span> <span style=''>prior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>on</span> <span style=''>its</span> <span style='background-color:r ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Selection</span> <span style=''>Bias</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Correction</span> <span style=''>Theory</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3083700440528634);'>theoretical</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>bias</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correction</span> <span style=''>The</span> <span style=''>sample</span> <span style=''>bias</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correction</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>commonly</span> <span style=''>used</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>consists</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reweighting</span> <span style=''>the</span> <span style=''>cost</span> <span style=''>of</span> <span style=''>an</span> <span style=''>error</span> <span style=''>on</span> <span style=''>each</span> <span style=''>training</span> <span style=''>point</span> <span style=''>of</span> <span style=''>a</span> <span style=''>biased</span> <span style=''>sample</span> <span style=''>to</span> <span style=''>more</span> <span style=''>closely</span> <span style=''>reflect</span> <span style=''>the</span> <span style=''>unbiased</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>This</span> <span style=''>relies</span> <span style=''>on</span> <span style=''>weights</span> <span style=''>derived</span> <span style=''>by</span> <span style=''>various</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>based</span> <span style=''>on</span> <span style=''>finite</span> <span style=''>samples</span> <span style=''>We</span> <span style=''>analyze</span> <span style=''>the</span> <span style=''>effect</span> <span style=''>of</span> <span style=''>an</span> <span style=''>error</span> <span style=''>in</span> <span style=''>that</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>on</span> <span style=''>the</span> <span style=''>accuracy</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hypothesis</span> <span style=''>returned</span> <span style=''>by</span> <span style=''>the</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>a</span> <span style=''>cluster</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>and</span> <span style=''>kernel</span> <span style=''>mean</span> <span style=''>matching</span> <span style=''>We</span> <span style=''>also</span> <span style=''>report</span> <span style=''>the</span> <span style=''>results</span> <span style=''>of</span> <span style=''>sample</span> <span style=''>bias</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correction</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiments</span> <span style=''>with</span> <span style=''>several</span> <span style=''>data</span> <span style=''>sets</span> <span style=''>using</span> <span style=''>these</span> <span style='backgroun ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Houdini</span> <span style=''>Fooling</span> <span style=''>Deep</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Prediction</span> <span style=''>Models</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Generating</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>examples</span> <span style=''>is</span> <span style=''>a</span> <span style=''>critical</span> <span style=''>step</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluating</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improving</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>robustness</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>machines</span> <span style=''>So</span> <span style=''>far</span> <span style=''>most</span> <span style=''>existing</span> <span style=''>methods</span> <span style=''>only</span> <span style=''>work</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>and</span> <span style=''>are</span> <span style=''>not</span> <span style=''>designed</span> <span style=''>to</span> <span style=''>alter</span> <span style=''>the</span> <span style=''>true</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>measure</span> <span style=''>of</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>at</span> <span style=''>hand</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>flexible</span> <span style=''>approach</span> <span style=''>named</span> <span style=''>Houdini</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generating</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>examples</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specifically</span> <span style=''>tailored</span> <span style=''>for</span> <span style=''>the</span> <span style=''>final</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>measure</span> <span style=''>of</span> <span style=''>the</span> <span style=''>task</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considered</span> <span style=''>be</span> <span style=''>it</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combinatorial</span> <span style=''>and</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decomposable</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>successfully</span> <span style=''>apply</span> <span style=''>Houdini</span> <span style=''>to</span> <span style=''>a</span> <span style=''>range</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>such</span> <span style=''>as</span> <span style=''>speech</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognition</span> <span style=''>pose</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>and</span> <span style=''>semantic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>segmentation</span> <span style=''>In</span> <span style=''>all</span> <span style=''>cases</span> <span style=''>the</span> <span style=''>attacks</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Houdini</span> <span style=''>achieve</span> <span style=''>higher</span> <span style=''>success</span> <span style=''>rate</span> <span style=''>than</span> <span style=''>those</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09974973185555953)
# 	experimental (0.13621737575974258)
# 	architecture (0.08759385055416517)
# 	challenging (0.10833035395066143)
# 	segmentation (0.0736503396496246)
# 	information (0.2373972112978191)
# 	different (0.2524132999642474)
# 	detection (0.12263139077583125)
# 	recognition (0.12298891669646049)
# 	convolutional (0.13800500536288882)
#
# Some Statistics words are:
# 	statistical (0.14228657014478283)
# 	stochastic (0.13579630554168748)
# 	theoretical (0.14827758362456314)
# 	variables (0.13579630554168748)
# 	estimation (0.16375436844732902)
# 	algorithm (0.3939091362955567)
# 	distribution (0.18472291562656015)
# 	dimensional (0.18472291562656015)
# 	regression (0.17473789316025962)
# 	inference (0.2091862206689965)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="89842742-57dd-4ce8-b31f-39c0ee46cc46" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("89842742-57dd-4ce8-b31f-39c0ee46cc46")) {                    Plotly.newPlot(                        "89842742-57dd-4ce8-b31f-39c0ee46cc46",                        [{"x":["technique","expensive","sequential","reinforcement","randomization","performance","employing","experiments","simulator","experimentally","observations","asymmetric","promising","dangerous","simulated","significant","algorithm","significantly","simulation","challenges","transferring","observability","advantage","reporting","background","principled","likelihood","recognition","demonstrates","treatment","traditional","calibration","distribution","parameters","estimating","introduce","probabilistic","notoriously","algorithms","competing","orthogonal","positives","investigate","structured","applicability","strategies","structure","highlight","stability","increases","strengths","guidelines","selection","validation","reliability","controlling","difficult","weaknesses","demonstrated","conjunction","decreasing","optimization","convergence","generalizes","direction","understanding","functions","regularization","converges","methodology","regression","unregularized","extremely","continuing","restricted","logarithmic","separable","furthermore","supervised","probability","splitting","represent","framework","multilayer","transformations","unsupervised","activation","differentiability","requiring","demonstrate","nonlinear","integration","synergistic","architecture","separability","clustering","particular","classification","perceptron","learnable","independent","comparison","decomposing","techniques","literature","dimension","recursively","distributions","filtering","tensorflow","estimation","efficiency","including","available","implemented","nonparametric","resulting","advantages","synthetic","benchmarks","conditional","smoothing","applications","partitioning","generative","numerical","diagnosis","introduced","properties","constrained","specified","fundamental","desirable","prioritized","guaranteed","inequalities","classifiers","construct","counterparts","statistical","classical","concerned","priorities","theoretical","dimensional","embarrassingly","conditions","distributed","exponential","facilitate","communicating","conditionally","theoretically","procedure","developed","restrictive","independently","nonconjugate","empirically","variational","conjugate","inference","implementation","describes","technical","carefully","automated","consequences","interested","translation","arithmetic","connection","elimination","correction","recursive","unification","influence","historians","consistency","improving","aggregates","intermediate","mechanisms","benchmark","alternate","comparable","innovative","interesting","outperforms","examining","architectures","popularized","approaches","neighborhood","connected","surprisingly","designing","mechanism","propagation","neighbors","attention","predictions","foundation","faithfully","biologically","incentives","prediction","usefulness","maximizing","backpropagate","discretizing","perspective","plasticity","utilities","plausible","constraints","different","depending","propositional","attribute","preferential","procedures","accordance","combining","averaging","tomography","considering","detection","obstructive","pulmonary","instances","propagated","assumptions","quantification","incorrectly","quantified","previously","classifying","graphical","corollary","convexity","typically","corroborate","complexity","sufficient","simulations","guarantees","condition","knowledge","obstacles","convolutional","boundaries","accurately","demonstrations","incorporate","inco ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	unregularized
# 	nonconjugate
# 	ascending
# 	delineates
# 	trilinear
# 	isometrically
# 	deconvnet
# 	violating
# 	samplings
# 	physiologic
# 	hypernetworks
# 	hypernetwork
# 	exchangeability
# 	corruptions
# 	explanatory
# 	supernova
# 	terabytes
# 	percolation
# 	metabolite
# 	resistance
# Some words which never appear in Statistics papers:
# 	historians
# 	plasticity
# 	propositional
# 	obstructive
# 	obstacles
# 	sigmoidal
# 	programmable
# 	exchanging
# 	precondition
# 	ecological
# 	junctions
# 	cooperative
# 	navigable
# 	acknowledged
# 	fuzzification
# 	plausibility
# 	necessitates
# 	multispectral
# 	discounting
# 	surpassing

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.081854043392505e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7758333333333334
